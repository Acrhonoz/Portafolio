# %%
import pandas as pd
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# ### EJERCICIO 1: MODELO SUPERVISADO.

# %%
df = pd.read_excel('/Users/acrhonoz./Desktop/base_modelo_supervisado.xlsx')

# %%
df
# Out:
#         ID  X1  X2    X3    X4     X5     X6     X7     X8     Y
# 0        1   2   4  10.0  10.0  10.00  10.00  10.00  10.00  10.0
# 1        2   1  21   5.0   7.0   5.00   8.07   8.34  12.74   5.0
# 2        3   1   2   7.0   9.0   9.00   6.00   6.00   6.00   8.0
# 3        4   1   3   8.0   9.0   9.00   8.00  10.00   5.00   6.0
# 4        5   2   2  10.0  10.0  10.00  10.00  10.00  10.00  10.0
# ...    ...  ..  ..   ...   ...    ...    ...    ...    ...   ...
# 1995  1996   2   3   8.0  10.0  10.00  10.00  10.00  10.00  10.0
# 1996  1997   1   2   8.0   9.0   6.00   8.07   8.34  12.74   8.0
# 1997  1998   1   2   8.0   8.0   8.44   7.00   7.00   7.00   7.0
# 1998  1999   2   2  10.0  10.0   8.00   8.07   8.34  12.74  10.0
# 1999  2000   1   2  10.0  10.0  10.00   8.07   8.34  12.74  10.0
#
# [2000 rows x 10 columns]

# %%
# Variables predictoras
X_multiple = df.iloc[:,1:9]

# %%
X_multiple
# Out:
#       X1  X2    X3    X4     X5     X6     X7     X8
# 0      2   4  10.0  10.0  10.00  10.00  10.00  10.00
# 1      1  21   5.0   7.0   5.00   8.07   8.34  12.74
# 2      1   2   7.0   9.0   9.00   6.00   6.00   6.00
# 3      1   3   8.0   9.0   9.00   8.00  10.00   5.00
# 4      2   2  10.0  10.0  10.00  10.00  10.00  10.00
# ...   ..  ..   ...   ...    ...    ...    ...    ...
# 1995   2   3   8.0  10.0  10.00  10.00  10.00  10.00
# 1996   1   2   8.0   9.0   6.00   8.07   8.34  12.74
# 1997   1   2   8.0   8.0   8.44   7.00   7.00   7.00
# 1998   2   2  10.0  10.0   8.00   8.07   8.34  12.74
# 1999   1   2  10.0  10.0  10.00   8.07   8.34  12.74
#
# [2000 rows x 8 columns]

# %%
#Etiquetas 
Y_multiple = df.iloc[:,9:10]

# %%
Y_multiple
# Out:
#          Y
# 0     10.0
# 1      5.0
# 2      8.0
# 3      6.0
# 4     10.0
# ...    ...
# 1995  10.0
# 1996   8.0
# 1997   7.0
# 1998  10.0
# 1999  10.0
#
# [2000 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(X_multiple,Y_multiple,test_size=0.2)

# %%
rl_multiple = linear_model.LinearRegression()

# %%
rl_multiple.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print('DATOS DEL MODELO DE REGRESIÓN LINEAL MULTIPLE')
print()
print('valor de los coeficientes: ')
print()
print(rl_multiple.coef_)
print()
print('valor de la intersección:')
print()
print(rl_multiple.intercept_)
# Out:
# DATOS DEL MODELO DE REGRESIÓN LINEAL MULTIPLE
#
# valor de los coeficientes:
#
# [[ 0.08276935  0.00446661  0.94454185  0.1276722   0.02218391  0.00840576
#    0.03684803 -0.00302719]]
#
# valor de la intersección:
#
# [-1.3946406]

# %%
#Precisión del Modelo
print('Precisión del modelo: ')
print(rl_multiple.score(x_train,y_train))
# Out:
# Precisión del modelo:
# 0.7487436913609256

# %%
# Importancia de las características
importances = pd.DataFrame(data={
    'Attribute': x_train.columns,
    'Importance': rl_multiple.coef_[0]
})
importances = importances.sort_values(by='Importance', ascending=False)

# %%
plt.bar(x=importances['Attribute'], height=importances['Importance'], color='#087E8B')
plt.title('Importanacia de las características obtenidas de los coeficientes', size=20)
plt.xticks(rotation='vertical')
plt.show()

# %%
# d) El valor de los coeficientes de las características
# e) Por el valor de R cuadrada,
# f) El modelo se puede mejorar, eliminando las caractristicas con el valor de coeficientes mas pequeños, pues entre mas 
# cercanos estén a 0 menor es el impacto que tienen sobre el modelo
